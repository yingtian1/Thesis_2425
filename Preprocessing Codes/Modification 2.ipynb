# %%
import pandas as pd
import os

# Try using openpyxl as an engine
xls = pd.ExcelFile('coal_supply_chain_india.xlsx', engine='openpyxl')
all_sheets = {sheet_name: pd.read_excel(xls, sheet_name=sheet_name) for sheet_name in xls.sheet_names}

# %%
assets = all_sheets['assets']
ownership = all_sheets['ownership']
flood_exposure = all_sheets['flood exposure']
firms = all_sheets['firms']
supply_chain = all_sheets['supply chain']

# %%
# Subtract 1 from firm_id to make it start from 0
firms['firm_id'] = firms['firm_id'] - 1

# %%
firms
# Out:
#      firm_id                       name  final_demand  discount_rate  \
# 0          0                          -           100           0.05
# 1          1  24R Advisory Services Pvt            25           0.05
# 2          2                ACB (India)            50           0.05
# 3          3        AM Mining India Pvt            25           0.05
# 4          4                      AM/NS           100           0.05
# ..       ...                        ...           ...            ...
# 159      159       Wilmar International            50           0.05
# 160      160                   Yes Bank            25           0.05
# 161      161          natural person(s)            50           0.05
# 162      162       small shareholder(s)           100           0.05
# 163      163                    unknown            25           0.05
#
#      unit_price  margin  leverage_ratio        type
# 0            20    0.02            0.02  production
# 1            20    0.02            0.02  production
# 2            20    0.02            0.02  production
# 3            20    0.02            0.02  production
# 4            20    0.02            0.02  production
# ..          ...     ...             ...         ...
# 159          20    0.02            0.02  production
# 160          20    0.02            0.02  production
# 161          20    0.02            0.02  production
# 162          20    0.02            0.02  production
# 163          20    0.02            0.02  production
#
# [164 rows x 8 columns]

# %%
# Create a mapping from asset_id to name
id_to_name = assets.set_index('asset_id')['name']

# Map the name column
ownership['name'] = ownership['asset_id'].map(id_to_name)

ownership
# Out:
#       asset_id  share  firm_id                               name
# 0          358    1.0       11  Adani Raigarh Thermal Power Plant
# 1          359    1.0       59     Aditya Aluminium power station
# 2          360    1.0       59     Aditya Aluminium power station
# 3          361    1.0       59     Aditya Aluminium power station
# 4          362    1.0       59     Aditya Aluminium power station
# ...        ...    ...      ...                                ...
# 1386      1206    1.0       48            Bedi Port Coal Terminal
# 1387      1212    1.0       49          Haldia Port Coal Terminal
# 1388      1219    1.0        1        Karaikal Port Coal Terminal
# 1389      1207    1.0       35          Cochin Port Coal Terminal
# 1390      1215    1.0       73         Jaigarh Port Coal Terminal
#
# [1391 rows x 4 columns]

# %%
ownership['firm_id'] = ownership['firm_id'] - 1
ownership
# Out:
#       asset_id  share  firm_id                               name
# 0          358    1.0       10  Adani Raigarh Thermal Power Plant
# 1          359    1.0       58     Aditya Aluminium power station
# 2          360    1.0       58     Aditya Aluminium power station
# 3          361    1.0       58     Aditya Aluminium power station
# 4          362    1.0       58     Aditya Aluminium power station
# ...        ...    ...      ...                                ...
# 1386      1206    1.0       47            Bedi Port Coal Terminal
# 1387      1212    1.0       48          Haldia Port Coal Terminal
# 1388      1219    1.0        0        Karaikal Port Coal Terminal
# 1389      1207    1.0       34          Cochin Port Coal Terminal
# 1390      1215    1.0       72         Jaigarh Port Coal Terminal
#
# [1391 rows x 4 columns]

# %%
supply_chain['supplier'] = supply_chain['supplier'] - 1
supply_chain['client'] = supply_chain['client'] - 1
supply_chain
# Out:
#      supplier  client    recipe        product
# 0          26       7  0.070721  subbituminous
# 1          26      87  0.374552        unknown
# 2          26     140  0.949854        unknown
# 3         138       7  0.389144  subbituminous
# 4         138      87  0.031325        unknown
# ..        ...     ...       ...            ...
# 288       103      10  0.816487     bituminous
# 289       127      10  0.888567     bituminous
# 290        51      10  0.459195     bituminous
# 291       142      10  0.169498     bituminous
# 292       102     142  0.555483        unknown
#
# [293 rows x 4 columns]

# %%
# use asset level instead of unit level
assets_grouped = assets.groupby('name').agg({
    'asset_id': 'first',
    'latitude': 'first',
    'longitude': 'first',
    'country': 'first',
    'product': 'first',
    'replacement_value': 'sum',
    'production': 'sum'
}).reset_index()

# %%
assets_grouped
# Out:
#                                                name  asset_id   latitude  \
# 0                                     AKK Coal Mine         3  23.790500
# 1    ARS Metals Gummidipoondi captive power station       409  13.423889
# 2                                     ASP Coal Mine       329  23.741330
# 3                         Adani Godda power station       356  24.814107
# 4                 Adani Raigarh Thermal Power Plant       358  21.743775
# ..                                              ...       ...        ...
# 667                           West Bokaro Coal Mine       112  23.792747
# 668                      West Jhagrakhand Coal Mine       194  23.197211
# 669                           Yadadri power station      1201  16.708219
# 670                          Yermarus power station      1203  16.295261
# 671                       Zawar Mines power station      1205  24.580000
#
#      longitude country product  replacement_value  production
# 0    85.919800   India   power       9.309546e+06       5.350
# 1    80.066111   India   power       5.742337e+07      33.000
# 2    86.405159   India   power       7.151819e+05       0.411
# 3    87.135465   India   power       1.531290e+09     880.000
# 4    83.274093   India   power       5.742337e+08     330.000
# ..         ...     ...     ...                ...         ...
# 667  85.554231   India   power       1.131066e+07       6.500
# 668  82.161616   India   power       2.088122e+05       0.120
# 669  79.581184   India   power       1.531290e+09     880.000
# 670  77.356120   India   power       1.531290e+09     880.000
# 671  73.680000   India   power       7.656449e+07      44.000
#
# [672 rows x 8 columns]

# %%
ownership_grouped = ownership.groupby(['name', 'firm_id'], as_index=False).first()

# %%
ownership_grouped
# Out:
#                                                name  firm_id  asset_id  share
# 0                                     AKK Coal Mine       33         3  1.000
# 1    ARS Metals Gummidipoondi captive power station        7       409  1.000
# 2                                     ASP Coal Mine       33       329  1.000
# 3                         Adani Godda power station       10       356  1.000
# 4                 Adani Raigarh Thermal Power Plant       10       358  1.000
# ..                                              ...      ...       ...    ...
# 731                      West Jhagrakhand Coal Mine       33       194  1.000
# 732                           Yadadri power station      142      1201  1.000
# 733                          Yermarus power station       22      1203  0.221
# 734                          Yermarus power station       86      1203  0.779
# 735                       Zawar Mines power station       60      1205  1.000
#
# [736 rows x 4 columns]

# %%
assets_grouped = assets_grouped.drop(columns=['asset_id'])
ownership_grouped = ownership_grouped.drop(columns=['asset_id'])

# %%
assets_grouped
# Out:
#                                                name   latitude  longitude  \
# 0                                     AKK Coal Mine  23.790500  85.919800
# 1    ARS Metals Gummidipoondi captive power station  13.423889  80.066111
# 2                                     ASP Coal Mine  23.741330  86.405159
# 3                         Adani Godda power station  24.814107  87.135465
# 4                 Adani Raigarh Thermal Power Plant  21.743775  83.274093
# ..                                              ...        ...        ...
# 667                           West Bokaro Coal Mine  23.792747  85.554231
# 668                      West Jhagrakhand Coal Mine  23.197211  82.161616
# 669                           Yadadri power station  16.708219  79.581184
# 670                          Yermarus power station  16.295261  77.356120
# 671                       Zawar Mines power station  24.580000  73.680000
#
#     country product  replacement_value  production
# 0     India   power       9.309546e+06       5.350
# 1     India   power       5.742337e+07      33.000
# 2     India   power       7.151819e+05       0.411
# 3     India   power       1.531290e+09     880.000
# 4     India   power       5.742337e+08     330.000
# ..      ...     ...                ...         ...
# 667   India   power       1.131066e+07       6.500
# 668   India   power       2.088122e+05       0.120
# 669   India   power       1.531290e+09     880.000
# 670   India   power       1.531290e+09     880.000
# 671   India   power       7.656449e+07      44.000
#
# [672 rows x 7 columns]

# %%
# 1. Create new numeric asset_id
assets_grouped['asset_id'] = range(len(assets_grouped))

# 2. Move asset_id to the first column
cols = ['asset_id'] + [col for col in assets_grouped.columns if col != 'asset_id']
assets_grouped = assets_grouped[cols]

# %%
assets_grouped
# Out:
#      asset_id                                            name   latitude  \
# 0           0                                   AKK Coal Mine  23.790500
# 1           1  ARS Metals Gummidipoondi captive power station  13.423889
# 2           2                                   ASP Coal Mine  23.741330
# 3           3                       Adani Godda power station  24.814107
# 4           4               Adani Raigarh Thermal Power Plant  21.743775
# ..        ...                                             ...        ...
# 667       667                           West Bokaro Coal Mine  23.792747
# 668       668                      West Jhagrakhand Coal Mine  23.197211
# 669       669                           Yadadri power station  16.708219
# 670       670                          Yermarus power station  16.295261
# 671       671                       Zawar Mines power station  24.580000
#
#      longitude country product  replacement_value  production
# 0    85.919800   India   power       9.309546e+06       5.350
# 1    80.066111   India   power       5.742337e+07      33.000
# 2    86.405159   India   power       7.151819e+05       0.411
# 3    87.135465   India   power       1.531290e+09     880.000
# 4    83.274093   India   power       5.742337e+08     330.000
# ..         ...     ...     ...                ...         ...
# 667  85.554231   India   power       1.131066e+07       6.500
# 668  82.161616   India   power       2.088122e+05       0.120
# 669  79.581184   India   power       1.531290e+09     880.000
# 670  77.356120   India   power       1.531290e+09     880.000
# 671  73.680000   India   power       7.656449e+07      44.000
#
# [672 rows x 8 columns]

# %%
ownership_grouped
# Out:
#                                                name  firm_id  share
# 0                                     AKK Coal Mine       33  1.000
# 1    ARS Metals Gummidipoondi captive power station        7  1.000
# 2                                     ASP Coal Mine       33  1.000
# 3                         Adani Godda power station       10  1.000
# 4                 Adani Raigarh Thermal Power Plant       10  1.000
# ..                                              ...      ...    ...
# 731                      West Jhagrakhand Coal Mine       33  1.000
# 732                           Yadadri power station      142  1.000
# 733                          Yermarus power station       22  0.221
# 734                          Yermarus power station       86  0.779
# 735                       Zawar Mines power station       60  1.000
#
# [736 rows x 3 columns]

# %%
# Create the mapping from assets_grouped
name_to_asset_id = assets_grouped.set_index('name')['asset_id']

# Map the asset_id in ownership_grouped using the name
ownership_grouped['asset_id'] = ownership_grouped['name'].map(name_to_asset_id)

# Move asset_id to the first column
ownership_grouped = ownership_grouped[['asset_id'] + [col for col in ownership_grouped.columns if col != 'asset_id']]

ownership_grouped = ownership_grouped.drop(columns=['name'])

# %%
ownership_grouped
# Out:
#      asset_id  firm_id  share
# 0           0       33  1.000
# 1           1        7  1.000
# 2           2       33  1.000
# 3           3       10  1.000
# 4           4       10  1.000
# ..        ...      ...    ...
# 731       668       33  1.000
# 732       669      142  1.000
# 733       670       22  0.221
# 734       670       86  0.779
# 735       671       60  1.000
#
# [736 rows x 3 columns]

# %%
flood_exposure = flood_exposure = flood_exposure.head(672)
# Reset asset_id to start from 0 in flood_exposure
flood_exposure['asset_id'] = range(len(flood_exposure))
flood_exposure
# Out:
# /var/folders/3h/83jfd71114x78b1sj0_llf1m0000gp/T/ipykernel_7478/2070315844.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   flood_exposure['asset_id'] = range(len(flood_exposure))
#      asset_id     5     10     25     50    100    200    500   1000  \
# 0           0  9.34  10.15  11.61  13.28  13.57  14.11  14.81  15.19
# 1           1  0.43   0.55   0.66   0.72   0.79   0.85   0.91   0.98
# 2           2  2.05   2.25   2.47   2.58   2.60   2.61   2.62   2.62
# 3           3  2.05   2.25   2.47   2.58   2.60   2.61   2.62   2.62
# 4           4  0.20   1.07   2.85   2.86   3.92   4.62   5.26   5.67
# ..        ...   ...    ...    ...    ...    ...    ...    ...    ...
# 667       667  9.34  10.15  11.61  13.28  13.57  14.11  14.81  15.19
# 668       668  2.05   2.25   2.47   2.58   2.60   2.61   2.62   2.62
# 669       669  0.20   1.07   2.85   2.86   3.92   4.62   5.26   5.67
# 670       670  2.70   2.70   2.76   3.03   3.34   3.59   3.81   3.96
# 671       671  2.05   2.25   2.47   2.58   2.60   2.61   2.62   2.62
#
#      flood_protection
# 0               10.15
# 1                0.55
# 2                2.25
# 3                2.25
# 4                1.07
# ..                ...
# 667             10.15
# 668              2.25
# 669              1.07
# 670              2.70
# 671              2.25
#
# [672 rows x 10 columns]

# %%
# Update the required sheets (assets and ownership)
all_sheets['assets'] = assets_grouped
all_sheets['ownership'] = ownership_grouped
all_sheets['flood exposure'] = flood_exposure
all_sheets['flood exposure'] = flood_exposure
all_sheets['firms'] = firms
all_sheets['supply chain'] = supply_chain

# Write all sheets back to a new Excel file (rename after saving)
with pd.ExcelWriter('coal_supply_chain_india_updated.xlsx', engine='xlsxwriter') as writer:
    for sheet_name, df in all_sheets.items():
        df.to_excel(writer, sheet_name=sheet_name, index=False)
